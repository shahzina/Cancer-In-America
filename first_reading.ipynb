# %% [markdown]
# Group Project 2
# Web Visualization

# %%
import csv
import json
import pandas as pd
import sys, getopt, pprint
import pymongo

# %%
# read in the 5 yr average cancer incidence rate by county
file1 = "incidence5yrbyCounty.csv"
df_incid5_cty = pd.read_csv(file1)
cty_incid5_df=df_incid5_cty
cty_incid5_df.head()
# Out:
#                           County   FIPS  Age_Adjusted_Rate State
# 0  Autauga County, Alabama(6,10)   1001              482.1    AL
# 1  Baldwin County, Alabama(6,10)   1003              437.3    AL
# 2  Barbour County, Alabama(6,10)   1005              424.3    AL
# 3     Bibb County, Alabama(6,10)   1007              473.0    AL
# 4   Blount County, Alabama(6,10)   1009              423.7    AL

# %%
# read in the county health ranking data
file2 = "2015_countydata.csv"
df_cnty_d = pd.read_csv(file2)
rank_cntydat_df=df_cnty_d
rank_cntydat_df.head()
# Out:
#    statecode  countycode  fipscode state           county  year  Smoker  \
# 0          1           1      1001    AL   Autauga County  2015   0.217
# 1          4           1      4001    AZ    Apache County  2015   0.184
# 2          5           1      5001    AR  Arkansas County  2015   0.220
# 3          6           1      6001    CA   Alameda County  2015   0.106
# 4          8           1      8001    CO     Adams County  2015   0.216
#
#    Obese  Food Environment Index  Alcohol  Mammogram  Unemployment  \
# 0  0.313                     7.2    0.167   0.687980      0.056875
# 1  0.319                     0.9    0.134   0.318408      0.197965
# 2  0.351                     6.1    0.115   0.446429      0.066535
# 3  0.205                     7.6    0.194   0.600738      0.074132
# 4  0.249                     7.7    0.189   0.502252      0.075426
#
#    Air Polution  Population
# 0         12.92       55246
# 1          9.82       71934
# 2         12.27       18777
# ...

# %%
#  read in the county cancer list data? 2015
#

# %%
# read in the 5 yr average cancer incidence rate by state
file3 = "incidence5yrbyState.csv"
df_incid5_st = pd.read_csv(file3)
st_incid5_df=df_incid5_st
st_incid5_df.head()
# Out:
#   State  Age_Adjust_Rate_State
# 0    AK                10181.7
# 1    AL                29845.2
# 2    AR                33279.0
# 3    AZ                 5272.1
# 4    CA                23813.9

# %%
# read in the state health ranking data
file4 = "2015_statedata.csv"
df_state_d = pd.read_csv(file4)
rank_stdat_df=df_state_d
rank_stdat_df.head()
# Out:
#    statecode  countycode  fipscode state      county  year  Smoker     Obese  \
# 0          1           0      1000    AL     Alabama  2015   0.219  0.332268
# 1          2           0      2000    AK      Alaska  2015   0.208  0.283441
# 2          4           0      4000    AZ     Arizona  2015   0.166  0.238975
# 3          5           0      5000    AR    Arkansas  2015   0.224  0.328898
# 4          6           0      6000    CA  California  2015   0.129  0.229002
#
#    Food Environment Index  Alcohol  Mammogram  Unemployment  Air Polution  \
# 0                     6.7    0.122   0.627107      0.064638         12.80
# 1                     7.4    0.192   0.559037      0.065402           NaN
# 2                     6.9    0.161   0.639833      0.079746         10.12
# 3                     6.2    0.126   0.577840      0.075477         11.76
# 4                     7.5    0.172   0.592978      0.089451          9.30
#
#    Population
# 0     4833722
# 1      735132
# ...

# %%
# read in the state cancer list data
file5 = "cancer_2015.csv"
df_state_cancer = pd.read_csv(file5)
cancer_stdat_df=df_state_cancer
cancer_stdat_df.head()
# Out:
#   State  State Name  Brain and Other Nervous System  Breast  Cervix Uteri  \
# 0    AL     Alabama                             342    3863           237
# 1    AK      Alaska                              51     426            29
# 2    AZ     Arizona                             433    4655           241
# 3    AR    Arkansas                             210    2189           162
# 4    CA  California                            2385   26945          1427
#
#    Colon and Rectum  Corpus Uteri  Esophagus  Gallbladder  \
# 0              2493           610        292           53
# 1               294            83         22            0
# 2              2583           961        337           72
# 3              1582           430        157           25
# 4             14620          5665       1484          504
#
#    Kidney and Renal Pelvis                  ...                    \
# 0                     1050                  ...
# 1                      136                  ...
# ...
